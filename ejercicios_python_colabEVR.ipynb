# %% [markdown]
# <a href="https://colab.research.google.com/github/Elijahpe20/google_collab_evr/blob/main/ejercicios_python_colabEVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 30 Ejercicios de Python para Principiantes
# ## Ciencia de Datos 2025
#
# **Temas cubiertos:**
# - `print()` - Mostrar información
# - Variables y tipos de datos (`int`, `float`, `str`, `bool`)
# - Operaciones y cálculos básicos
#
# **Niveles:**
# - 🟢 Básico (Ejercicios 1-10)
# - 🟡 Intermedio (Ejercicios 11-20)
# - 🔴 Avanzado (Ejercicios 21-30)
#
# ---

# %% [markdown]
# # 🟢 NIVEL BÁSICO (Ejercicios 1-10)

# %% [markdown]
# ## Ejercicio 1: Mi primer mensaje
# Usa `print()` para mostrar el mensaje: **"¡Hola, estoy aprendiendo Python!"**

# %%
print ("¡Hola, estoy aprendiendo Python!")
# Out:
# ¡Hola, estoy aprendiendo Python!

# %% [markdown]
# ## Ejercicio 2: Presentación personal
# Escribe **3 líneas** usando `print()` para mostrar:
# - Tu nombre
# - Tu ciudad
# - Tu comida favorita

# %%
print ("Elías")
print ("Medellín")
print ("Caldo de gallina")
# Out:
# Elías
# Medellín
# Caldo de gallina

# %% [markdown]
# ## Ejercicio 3: Crear variables de texto
# Crea una variable llamada `saludo` que contenga el texto **"Buenos días"** y luego imprímela.

# %%
saludo = "buenos días"
print (saludo)
# Out:
# buenos días

# %% [markdown]
# ## Ejercicio 4: Variables numéricas enteras
# Crea una variable `mi_edad` con tu edad (número entero) y muéstrala con `print()`.

# %%
mi_edad = 39
print (mi_edad)
# Out:
# 39

# %% [markdown]
# ## Ejercicio 5: Variables decimales
# Crea una variable `temperatura` con el valor **36.5** (un float) e imprímela.

# %%
temperatura = 36.5
print (temperatura)
# Out:
# 36.5

# %% [markdown]
# ## Ejercicio 6: Variables booleanas
# Crea una variable `es_mayor_de_edad` con valor `True` o `False` según tu caso, e imprímela.

# %%
es_mayor_de_edad = "true"
print (es_mayor_de_edad)
# Out:
# true

# %% [markdown]
# ## Ejercicio 7: Suma simple
# Crea dos variables `a = 15` y `b = 27`. Calcula su suma, guárdala en `resultado` e imprímela.

# %%
a = 15
b = 27
print (a + b)
# Out:
# 42

# %% [markdown]
# ## Ejercicio 8: Multiplicación
# Crea las variables `precio = 50` y `cantidad = 4`. Calcula el total y muéstralo.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 9: Imprimir múltiples variables
# Crea las variables `nombre = "Pedro"`, `edad = 30`, `ciudad = "Lima"`. Imprime las tres en una sola línea usando `print()`.

# %%
nombre = "Pedro"
edad = "30"
ciudad = "Lima"
print (nombre, edad, ciudad)
# Out:
# Pedro 30 Lima

# %% [markdown]
# ## Ejercicio 10: Promedio de dos números
# Calcula el promedio de `nota1 = 14` y `nota2 = 18`. Muestra el resultado.

# %%
nota1 = 14
nota2 = 18

print ((nota1+nota2)/2)
# Out:
# 16.0

# %% [markdown]
# ---
# # 🟡 NIVEL INTERMEDIO (Ejercicios 11-20)

# %% [markdown]
# ## Ejercicio 11: Ficha personal completa
# Crea variables para: `nombre` (str), `apellido` (str), `edad` (int), `peso` (float), `es_estudiante` (bool).
# Imprime todas las variables con etiquetas descriptivas.

# %%
nombre = str
apellido = str
edad = int
peso = float
es_estudiante = bool
print (nombre, apellido, edad, peso, es_estudiante)
# Out:
# <class 'str'> <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %% [markdown]
# ## Ejercicio 12: Cálculo de descuento
# Un producto cuesta **S/. 180**. Tiene un descuento del **15%**.
# Calcula el monto del descuento y el precio final. Muestra ambos valores.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 13: Conversión de moneda
# Tienes **250 dólares**. El tipo de cambio es **3.75 soles por dólar**.
# Calcula cuántos soles tienes y muestra el resultado.

# %%
x = 250
y = 3.75
print (x*y)
# Out:
# 937.5

# %% [markdown]
# ## Ejercicio 14: Cálculo de IMC
# Calcula el Índice de Masa Corporal (IMC) usando:
# - `peso_kg = 68`
# - `altura_m = 1.70`
# - Fórmula: `IMC = peso_kg / (altura_m ** 2)`
#
# Muestra el resultado.

# %%
peso_kg = 68
altura_m = 1.70
IMC = peso_kg / (altura_m ** 2)
print (IMC)
# Out:
# 23.529411764705884

# %% [markdown]
# ## Ejercicio 15: Promedio de tres notas
# Calcula el promedio de tres exámenes: `examen1 = 15`, `examen2 = 12`, `examen3 = 18`.
# Muestra cada nota y el promedio final.

# %%
examen1 = 15
examen2 = 12
examen3 = 18

print ((examen1+examen2+examen3)/3)

# %% [markdown]
# ## Ejercicio 16: Área de un rectángulo
# Calcula el área de un rectángulo con `base = 12.5` y `altura = 8.3`.
# Fórmula: `area = base * altura`

# %%
base = 12.5
altura = 8.3
print (base*altura)
# Out:
# 103.75000000000001

# %% [markdown]
# ## Ejercicio 17: Uso de métodos de string
# Crea la variable `mensaje = "python es genial"`.
# - Imprime el mensaje en mayúsculas usando `.upper()`
# - Imprime el mensaje capitalizado usando `.capitalize()`

# %%
mensaje = "python es genial"
print (mensaje.upper())
print(mensaje.capitalize())
# Out:
# PYTHON ES GENIAL
# Python es genial

# %% [markdown]
# ## Ejercicio 18: Verificar inicio de texto
# Crea la variable `email = "usuario@gmail.com"`.
# Usa `.startswith()` para verificar si empieza con **"usuario"** y `.endswith()` para verificar si termina con **".com"**.

# %%
email = "usuario@gmail.com"
print (email.startswith("usuario"))
print (email.endswith(".com"))
# Out:
# True
# True

# %% [markdown]
# ## Ejercicio 19: Concatenación de strings
# Crea `nombre = "Ana"` y `apellido = "García"`.
# Crea una variable `nombre_completo` que una ambas con un espacio en medio e imprímela.

# %%
nombre = "Ana"
apellido = "García"
nombre_completo = nombre + " " + apellido
print (nombre_completo)
# Out:
# Ana García

# %% [markdown]
# ## Ejercicio 20: Cálculo de propina
# La cuenta del restaurante es **S/. 85**. Quieres dejar **10%** de propina.
# Calcula la propina y el total a pagar. Muestra ambos valores.

# %%
x = 85
y = 0.10
print("Propina", x*y)
print("Total a pagar",x - (x*y))
# Out:
# Propina 8.5
# Total a pagar 76.5

# %% [markdown]
# ---
# # 🔴 NIVEL AVANZADO (Ejercicios 21-30)

# %% [markdown]
# ## Ejercicio 21: Registro de producto (e-commerce)
# Crea un registro completo de un producto con:
# - `nombre_producto` (str)
# - `precio` (float)
# - `stock` (int)
# - `disponible` (bool)
# - `categoria` (str)
#
# Imprime un resumen formateado con etiquetas.

# %%
nombre_producto = str
precio = float
stock = int
disponible = bool
categoría = str
print (nombre_producto, precio, stock, disponible, categoría)
# Out:
# <class 'str'> <class 'float'> <class 'int'> <class 'bool'> <class 'str'>

# %% [markdown]
# ## Ejercicio 22: Cálculo de salario neto
# Un empleado tiene un `salario_bruto = 3500`.
# Se le descuenta **13%** de AFP y **5%** de seguro.
# Calcula el total de descuentos y el salario neto.

# %%
salario_bruto = 3500
descuento = 0.13
seguro = 0.15
print ("total de descuentos", salario_bruto * descuento)
print ("Salario total", salario_bruto - (salario_bruto * descuento))
# Out:
# total de descuentos 455.0
# Salario total 3045.0

# %% [markdown]
# ## Ejercicio 23: Conversión de temperatura
# Convierte **98.6 grados Fahrenheit** a Celsius.
# Fórmula: `celsius = (fahrenheit - 32) * 5 / 9`
#
# Muestra el resultado con una etiqueta descriptiva.

# %%
farenheit = 98.6
celsius = (farenheit - 32) * 5/9
print (celsius)
# Out:
# 37.0

# %% [markdown]
# ## Ejercicio 24: Interés simple
# Calcula el interés simple de un préstamo:
# - `capital = 10000`
# - `tasa_anual = 12` (porcentaje)
# - `tiempo_años = 2`
#
# Fórmula: `interes = capital * (tasa_anual/100) * tiempo_años`
#
# Muestra el interés y el monto total a pagar.

# %%
capital = 10000
tasa_anual = 0.12
tiempo_años = 2
interes = capital * (tasa_anual/100) * tiempo_años
print (interes)
# Out:
# 23.999999999999996

# %% [markdown]
# ## Ejercicio 25: Área y perímetro de un círculo
# Dado un `radio = 5`, calcula:
# - Área: `pi * radio ** 2`
# - Perímetro: `2 * pi * radio`
#
# Usa `pi = 3.14159`

# %%
radio = 5
pi = 3.14159
print ("Área", pi * radio ** 2)
print ("Perímetro", pi * radio)
# Out:
# Área 78.53975
# Perímetro 15.70795

# %% [markdown]
# ## Ejercicio 26: Tarjeta de presentación
# Crea una tarjeta de presentación usando `print()` con este formato:
# ```
# ╔══════════════════════════════╗
# ║      [TU NOMBRE]             ║
# ║      [TU PROFESIÓN]          ║
# ║      Tel: [TU TELÉFONO]      ║
# ║      Email: [TU EMAIL]       ║
# ╚══════════════════════════════╝
# ```

# %%
w = "Elías"
x = "Comunicador"
y = 3112065036
z = "veliasr86@gmail.com"
print("TU_NOMBRE", w)
print("TU_PROFESIÓN", x)
print("Tel:", y)
print("Email:", z)
# Out:
# TU_NOMBRE Elías
# TU_PROFESIÓN Comunicador
# Tel: 3112065036
# Email: veliasr86@gmail.com

# %% [markdown]
# ## Ejercicio 27: División de gastos
# Tres amigos van a un restaurante. La cuenta total es **S/. 156.50**.
# Calcula cuánto debe pagar cada uno si dividen en partes iguales.
# Muestra el total y el monto individual.

# %%
x = 3
y = 156.50
print ("Total_a_pagar", y)
print ("Pago_por_partes", y/x)
# Out:
# Total_a_pagar 156.5
# Pago_por_partes 52.166666666666664

# %% [markdown]
# ## Ejercicio 28: Cálculo de velocidad
# Un auto recorre **450 km** en **5.5 horas**.
# Calcula la velocidad promedio usando: `velocidad = distancia / tiempo`
#
# Muestra el resultado en km/h.

# %%
x = 450
y = 5.5
print ("velocidad", x/y)
# Out:
# velocidad 81.81818181818181

# %% [markdown]
# ## Ejercicio 29: Resumen de ventas diarias
# Una tienda tuvo las siguientes ventas en un día:
# - Mañana: S/. 850
# - Tarde: S/. 1200
# - Noche: S/. 650
#
# Calcula el total del día y el promedio por turno.
# Imprime un reporte formateado con todos los datos.

# %%
ventas_mañana = 850
ventas_tarde = 1200
ventas_noche = 650
print ("Total del día", ventas_mañana + ventas_tarde + ventas_noche)
print ("Promedio Total", ((ventas_mañana + ventas_tarde + ventas_noche)/3))
# Out:
# Total del día 2700
# Promedio Total 900.0

# %% [markdown]
# ## Ejercicio 30: Proyecto final - Perfil de datos personales
# Crea un programa que muestre tu perfil completo con:
#
# 1. **Datos personales:** nombre, edad, ciudad, profesión
# 2. **Datos físicos:** peso (kg), altura (m), IMC calculado
# 3. **Datos financieros:** salario mensual, gasto mensual promedio, ahorro mensual
#
# Muestra todo en un formato de reporte bonito usando `print()` con separadores y etiquetas.

# %%
Nombre = "Elías"
Edad = 39
Ciudad = "Lima"
Profesión = "Comunicador"
Peso = 77
Altura = 1.68
Salario_mensual = 5000000
Gasto_mensual_promedio = 3800000
Ahorro_mensual = 1200000
print(Nombre, Edad, Ciudad, Profesión, Peso, Altura, Salario_mensual, Gasto_mensual_promedio, Ahorro_mensual)
# Out:
# Elías 39 Lima Comunicador 77 1.68 5000000 3800000 1200000

# %% [markdown]
# ---
# # 🎉 ¡Felicitaciones!
# Has completado los 30 ejercicios de Python.
#
# **Próximos pasos:**
# - Revisa tus respuestas
# - Experimenta modificando los valores
# - Intenta crear tus propios ejercicios
#
# **¡Sigue practicando!** 🚀
